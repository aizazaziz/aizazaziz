# %% [markdown]
# <a href="https://colab.research.google.com/github/aizazaziz/Mixed-Projects/blob/main/Copy_of_Welcome_to_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("cars_dataset.csv")

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
df1 = df.drop_duplicates()
df1
# Out:
#       2016 Model dummy Fuel Type Images        Make       Make      Model  \
# 0            NaN          Diesel    NaN       Skoda       Skoda    Kodiaq
# 1            NaN          Diesel    NaN       Skoda       Skoda   Octavia
# 2            NaN          Petrol    NaN       Skoda       Skoda   Octavia
# 3            NaN          Diesel    NaN       Skoda       Skoda     Fabia
# 4            NaN          Diesel    NaN       Skoda       Skoda    Superb
# ...          ...   ...       ...    ...         ...         ...       ...
# 72430        NaN          Petrol    NaN  Volkswagen  Volkswagen     T-Roc
# 72431        NaN          Petrol    NaN  Volkswagen  Volkswagen     T-Roc
# 72432        NaN          Petrol    NaN  Volkswagen  Volkswagen    Tiguan
# 72433        NaN          Petrol    NaN  Volkswagen  Volkswagen    Tiguan
# 72434        NaN          Petrol    NaN  Volkswagen  Volkswagen   Touareg
#
#       Sales Button select Select Brand Transmission Units Button      Year  \
# ...

# %%
df1.isnull().sum()
# Out:
# 2016 Model      69572
# dummy               0
# Fuel Type           0
# Images          53744
# Make                0
# Make                0
# Model               0
# Sales Button        0
# select              0
# Select Brand    53744
# Transmission        0
# Units Button        0
# Year                0
# 2016            69572
# Engine Size         0
# Mileage             0
# Price               0
# Sales               0
# Tax                 0
# dtype: int64

# %%
print(df1.shape)
# Out:
# (71550, 19)

# %%
df2 = df1.dropna()
df2
# Out:
#          2016 Model dummy Fuel Type  \
# 5166          C-MAX          Diesel
# 5167    Grand C-MAX          Diesel
# 5168         Mondeo          Diesel
# 5169          C-MAX          Diesel
# 5170    Grand C-MAX          Diesel
# ...             ...   ...       ...
# 68926         B-MAX          Petrol
# 68927         B-MAX          Petrol
# 68928         B-MAX          Petrol
# 68929         B-MAX          Petrol
# 68930         Focus          Petrol
#
#                                                   Images  Make Make   \
# 5166   https://m.media-amazon.com/images/I/61+0h-qLU5...  Ford  Ford
# 5167   https://m.media-amazon.com/images/I/61+0h-qLU5...  Ford  Ford
# 5168   https://m.media-amazon.com/images/I/61+0h-qLU5...  Ford  Ford
# 5169   https://m.media-amazon.com/images/I/61+0h-qLU5...  Ford  Ford
# 5170   https://m.media-amazon.com/images/I/61+0h-qLU5...  Ford  Ford
# ...                                                  ...   ...   ...
# ...

# %%
print(df2.shape)
# Out:
# (606, 19)

# %%
df2 = df2.drop(columns=[])

# %%
df2.isnull().sum()
# Out:
# 2016 Model      0
# dummy           0
# Fuel Type       0
# Images          0
# Make            0
# Make            0
# Model           0
# Sales Button    0
# select          0
# Select Brand    0
# Transmission    0
# Units Button    0
# Year            0
# 2016            0
# Engine Size     0
# Mileage         0
# Price           0
# Sales           0
# Tax             0
# dtype: int64

# %%
df2.describe()
# Out:
#                2016  Engine Size        Mileage         Price         Sales  \
# count    606.000000   606.000000     606.000000    606.000000    606.000000
# mean    6766.443894     1.388944   48105.846535   6702.863036   6766.443894
# std     1563.594839     0.365079   19209.664598   1518.649738   1563.594839
# min     2995.000000     0.000000    7000.000000   2975.000000   2995.000000
# 25%     5831.750000     1.000000   34126.500000   5798.250000   5831.750000
# 50%     6500.000000     1.200000   46053.500000   6482.500000   6500.000000
# 75%     7323.750000     1.600000   59815.750000   7298.750000   7323.750000
# max    14735.000000     3.200000  130000.000000  14495.000000  14735.000000
#
#               Tax
# count  606.000000
# mean    63.580858
# std     72.363631
# min      0.000000
# 25%     20.000000
# 50%     30.000000
# 75%    145.000000
# max    300.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 606 entries, 5166 to 68930
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   2016 Model    606 non-null    object
#  1   dummy         606 non-null    object
#  2   Fuel Type     606 non-null    object
#  3   Images        606 non-null    object
#  4   Make          606 non-null    object
#  5   Make          606 non-null    object
#  6   Model         606 non-null    object
#  7   Sales Button  606 non-null    object
#  8   select        606 non-null    object
#  9   Select Brand  606 non-null    object
#  10  Transmission  606 non-null    object
#  11  Units Button  606 non-null    object
#  12  Year          606 non-null    object
#  13  2016          606 non-null    float64
#  14  Engine Size   606 non-null    float64
#  15  Mileage       606 non-null    int64
#  16  Price         606 non-null    int64
#  17  Sales         606 non-null    int64
# ...

# %%
from google.colab import files
df2.to_csv("cars.csv")
files.download("cars.csv")
